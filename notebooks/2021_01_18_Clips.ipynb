# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np


clips = loadmat('clips.mat')['clips']

# %%
plt.plot(clips[0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf405accc0>,
#  <matplotlib.lines.Line2D at 0x7fbf405acdd8>,
#  <matplotlib.lines.Line2D at 0x7fbf405acf28>,
#  <matplotlib.lines.Line2D at 0x7fbf405be0b8>]

# %%
plt.plot(clips[1])
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf406df160>,
#  <matplotlib.lines.Line2D at 0x7fbf406df278>,
#  <matplotlib.lines.Line2D at 0x7fbf406df3c8>,
#  <matplotlib.lines.Line2D at 0x7fbf406df518>]

# %%
plt.plot(clips[2])
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf407b42e8>,
#  <matplotlib.lines.Line2D at 0x7fbf407b4400>,
#  <matplotlib.lines.Line2D at 0x7fbf407b4550>,
#  <matplotlib.lines.Line2D at 0x7fbf407b46a0>]

# %%
plt.plot(clips[3])
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf4087ffd0>,
#  <matplotlib.lines.Line2D at 0x7fbf4088c128>,
#  <matplotlib.lines.Line2D at 0x7fbf4088c278>,
#  <matplotlib.lines.Line2D at 0x7fbf4088c3c8>]

# %%
plt.plot(clips[4])
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf4095e278>,
#  <matplotlib.lines.Line2D at 0x7fbf4095e390>,
#  <matplotlib.lines.Line2D at 0x7fbf4095e4e0>,
#  <matplotlib.lines.Line2D at 0x7fbf4095e630>]

# %%
plt.plot(clips[5])
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf409c6fd0>,
#  <matplotlib.lines.Line2D at 0x7fbf409d5160>,
#  <matplotlib.lines.Line2D at 0x7fbf409d52b0>,
#  <matplotlib.lines.Line2D at 0x7fbf409d5400>]

# %%
plt.plot(clips[6])
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf40aad128>,
#  <matplotlib.lines.Line2D at 0x7fbf40aad240>,
#  <matplotlib.lines.Line2D at 0x7fbf40aad390>,
#  <matplotlib.lines.Line2D at 0x7fbf40aad4e0>]

# %%
from loren_frank_data_processing.multiunit import get_multiunit_dataframe2
from src.parameters import ANIMALS
from loren_frank_data_processing import make_tetrode_dataframe

tetrode_info = make_tetrode_dataframe(ANIMALS)

# %%
epoch_key = ('remy', 35, 2)
tetrode_info.xs(epoch_key, drop_level=False)
# Out:
#                                     area deadchans depth hemisphere  maxcell  \
# animal day epoch tetrode_number
# remy   35  2     1                  lost        []    []        NaN      NaN
#                  2                   ca1    [3, 4]    []        NaN      NaN
#                  3                   ca1        []    []        NaN      NaN
#                  4                   ca1        []    []        NaN      NaN
#                  5                  dead       NaN    []        NaN      NaN
#                  6                   ca1        []    []        NaN      NaN
#                  7                   ca1         1    []        NaN      NaN
#                  8               can1ref        []    []        NaN      NaN
#                  9                   ca1        []    []        NaN      NaN
#                  10                  ca1        []    []        NaN      NaN
#                  11                  ca1        []    []        NaN      NaN
#                  12                  ca1        []    []        NaN      NaN
#                  13                  ca1        []    []        NaN      NaN
#                  14                  ca1        []    []        NaN      NaN
#                  15                  ca1        []    []        NaN      NaN
#                  16                 lost    [3, 4]    []        NaN      NaN
#                  17                  ca1        []    []        NaN      NaN
#                  18                 lost        []    []        NaN      NaN
#                  19                  ca1        []    []        NaN      NaN
#                  20                  ca1        []    []        NaN      NaN
#                  21                  ca1        []    []        NaN      NaN
#                  22                  ca1        []    []        NaN      NaN
#                  23                  ca1        []    []        NaN      NaN
#                  24                  ca1        []    []        NaN      NaN
#                  25                  ca1        []    []        NaN      NaN
#                  26                  ca1        []    []        NaN      NaN
#                  27              can2ref        []    []        NaN      NaN
#                  28                  ca1        []    []        NaN      NaN
#                  29                  ca1        []    []        NaN      NaN
#                  30                  ca1        []    []        NaN      NaN
#                  31                 dead       NaN    []        NaN      NaN
#                  32                 dead       NaN    []        NaN      NaN
#
#                                  nearCA2  numcells  representative subarea  \
# animal day epoch tetrode_number
# remy   35  2     1                   NaN       0.0             NaN     NaN
#                  2                   NaN       0.0             NaN    ca1E
#                  3                   NaN       0.0             NaN    ca1E
#                  4                   NaN       0.0             NaN     NaN
#                  5                   NaN       0.0             NaN     NaN
#                  6                   NaN       0.0             NaN     NaN
#                  7                   NaN       0.0             NaN    ca1E
#                  8                   NaN       0.0             NaN     NaN
#                  9                   NaN       0.0             NaN     NaN
#                  10                  NaN       0.0             NaN     NaN
#                  11                  NaN       0.0             NaN     NaN
#                  12                  NaN       0.0             NaN     NaN
#                  13                  NaN       0.0             NaN     NaN
#                  14                  NaN       0.0             NaN     NaN
#                  15                  NaN       0.0             NaN    ca1E
#                  16                  NaN       0.0             NaN     NaN
#                  17                  NaN       0.0             NaN    ca1E
#                  18                  NaN       0.0             NaN     NaN
#                  19                  NaN       0.0             NaN     NaN
#                  20                  NaN       0.0             NaN     NaN
#                  21                  NaN       0.0             NaN     NaN
#                  22                  NaN       0.0             NaN     NaN
#                  23                  NaN       0.0             NaN     NaN
#                  24                  NaN       0.0             NaN     NaN
#                  25                  NaN       0.0             NaN     NaN
#                  26                  NaN       0.0             NaN     NaN
#                  27                  NaN       0.0             NaN     NaN
#                  28                  NaN       0.0             NaN     NaN
#                  29                  NaN       0.0             NaN    ca1E
#                  30                  NaN       0.0             NaN     NaN
#                  31                  NaN       0.0             NaN     NaN
#                  32                  NaN       0.0             NaN     NaN
#
#                                 suparea      tetrode_id validripple
# animal day epoch tetrode_number
# remy   35  2     1                 can1  remy_35_02_001         NaN
#                  2                 can1  remy_35_02_002         NaN
#                  3                 can1  remy_35_02_003         NaN
#                  4                 can1  remy_35_02_004         NaN
#                  5                  NaN  remy_35_02_005         NaN
#                  6                 can1  remy_35_02_006         NaN
#                  7                 can1  remy_35_02_007         NaN
#                  8                  ctx  remy_35_02_008         NaN
#                  9                 can1  remy_35_02_009         NaN
#                  10                can1  remy_35_02_010         NaN
#                  11                can1  remy_35_02_011         NaN
#                  12                can1  remy_35_02_012         NaN
#                  13                can1  remy_35_02_013         NaN
#                  14                can1  remy_35_02_014         NaN
#                  15                can1  remy_35_02_015         NaN
#                  16                can2  remy_35_02_016         NaN
#                  17                can2  remy_35_02_017         NaN
#                  18                can2  remy_35_02_018         NaN
#                  19                can2  remy_35_02_019         NaN
#                  20                can2  remy_35_02_020         NaN
#                  21                can2  remy_35_02_021         NaN
#                  22                can2  remy_35_02_022         NaN
#                  23                can2  remy_35_02_023         NaN
#                  24                can2  remy_35_02_024         NaN
#                  25                can2  remy_35_02_025         NaN
#                  26                can2  remy_35_02_026         NaN
#                  27                 ctx  remy_35_02_027         NaN
#                  28                can2  remy_35_02_028         NaN
#                  29                can2  remy_35_02_029         NaN
#                  30                can2  remy_35_02_030         NaN
#                  31                 NaN  remy_35_02_031         NaN
#                  32                 NaN  remy_35_02_032         NaN
