# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from src.analysis import load_all_replay_info

replay_info = load_all_replay_info(brain_areas=['CA1'])

# %%
import numpy as np

replay_info.n_tetrodes.hist(bins=np.arange(0.5, 25.5))
# Out:
# <AxesSubplot:>

# %%
from src.visualization import plot_upset_classification
import os
from src.figure_utilities import save_figure

plot_upset_classification(replay_info.loc[replay_info.n_tetrodes > 6])

save_figure(os.path.join("Figure5-supplemental2", "figure5_upset_CA1_only"))
